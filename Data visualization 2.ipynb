# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
cars_data=pd.read_csv("Data/Toyota.csv - Toyota.csv.csv",index_col=0,na_values=["??","????"])
cars_data.head()
cars_data.size
# Out:
# 14360

# %%
cars_data.dropna(axis=0,inplace=True)
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5     12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1423   7950  80.0  35821.0   Petrol   86.0       0.0          1  1300      3
# 1424   7750  73.0  34717.0   Petrol   86.0       0.0          0  1300      3
# 1429   8950  78.0  24000.0   Petrol   86.0       1.0          1  1300      5
# 1430   8450  80.0  23000.0   Petrol   86.0       0.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 3       1165
# 4       1170
# 5       1170
# ...      ...
# 1423    1015
# 1424    1015
# 1429    1065
# 1430    1015
# 1435    1114
#
# [1096 rows x 10 columns]

# %%
sns.set(style='darkgrid')
sns.regplot(x=cars_data["Age"],y=cars_data["Price"])

# %%
sns.regplot(x=cars_data["Age"],y=cars_data["Price"],fit_reg=False)

# %%
sns.regplot(x=cars_data["Age"],y=cars_data["Price"],marker="*",fit_reg=False)

# %%
sns.lmplot(x='Age',y='Price',data=cars_data,fit_reg=False,hue='FuelType',legend=True,palette='Set3');

# %%
sns.distplot(cars_data["Age"])
# Out:
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cars_data["Age"],kde=False,bins=5)
# Out:
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x="FuelType",data=cars_data)

# %%
pd.crosstab(index=cars_data['Automatic'],columns=cars_data['FuelType'],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           12     116     910
# 1            0       0      58

# %%
sns.boxplot(x="FuelType",y=cars_data["Price"],hue="Automatic",data=cars_data)

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios":(.15,.85)})

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios":(.15,.85)})
sns.boxplot(cars_data["Price"],ax=ax_box)
sns.distplot(cars_data["Price"],ax=ax_hist,kde=False)
# Out:
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(cars_data,kind="scatter",hue="FuelType",diag_kws={"bw":0.1})
plt.show()
# Out:
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
data=np.random.randint(1,100,size=(10,10))
data
# Out:
# array([[53, 25, 48, 29, 67, 62,  1, 11, 55, 29],
#        [72, 58, 88, 65, 51, 34, 79, 19, 55, 33],
#        [97,  9, 77, 77, 45, 92,  6, 18, 90, 12],
#        [40, 10, 46, 22, 28, 84,  4, 60,  5, 66],
#        [67,  1, 90,  9, 73, 67, 40, 24, 67, 65],
#        [35, 33, 80, 61, 26, 72, 40, 48, 50, 45],
#        [ 8, 72, 20, 54, 84, 34, 23, 94, 24, 83],
#        [36, 70,  3, 13, 44, 67, 79, 43, 62, 14],
#        [17, 66, 29,  8, 39, 89, 58, 75,  9, 59],
#        [56, 84, 16, 33, 15, 95, 98, 71, 25, 46]])

# %%
sns.heatmap(data=data)

# %%
sns.heatmap(data=data,vmin=30,vmax=70)

# %%
cmap="tab20"
center=0
annot=True
hm=sns.heatmap(data=data,cmap=cmap,annot=annot)
plt.show()
